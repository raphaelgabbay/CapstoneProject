# %% [markdown]
# # This is my code forthe Capstone project

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# ## Addition Function

# %%
def addition(a, b):
    return a+b

# %%
print(addition(1,5))
